# %%
##import pandas
import pandas as pd

# %%
pd.read_csv("Documents/wk7-data/ems_2019_first_6_months.csv")
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             190010111  2019-01-01 00:24:51              SICK
# 1             190010112  2019-01-01 00:25:22              DRUG
# 2             190010113  2019-01-01 00:25:52              DRUG
# 3             190010114  2019-01-01 00:25:52             OBMAJ
# 4             190010115  2019-01-01 00:26:03               EDP
# ...                 ...                  ...               ...
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 4            DRUG
# ...

# %%
#call df
ems_19_first_df = pd.read_csv("documents/wk7-data/ems_2019_first_6_months.csv")

# %%
ems_19_first_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             190010111  2019-01-01 00:24:51              SICK
# 1             190010112  2019-01-01 00:25:22              DRUG
# 2             190010113  2019-01-01 00:25:52              DRUG
# 3             190010114  2019-01-01 00:25:52             OBMAJ
# 4             190010115  2019-01-01 00:26:03               EDP
# ...                 ...                  ...               ...
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 4            DRUG
# ...

# %%
ems_19_first_df.head()
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        190010111  2019-01-01 00:24:51              SICK
# 1        190010112  2019-01-01 00:25:22              DRUG
# 2        190010113  2019-01-01 00:25:52              DRUG
# 3        190010114  2019-01-01 00:25:52             OBMAJ
# 4        190010115  2019-01-01 00:26:03               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            6            SICK                          6
# 1                            4            DRUG                          4
# 2                            4            DRUG                          4
# 3                            3           OBMAJ                          3
# 4                            7             EDP                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    01/01/2019 12:25:28 AM                              Y
# ...

# %%
ems_19_first_df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        190010111  2019-01-01 00:24:51              SICK
# 1        190010112  2019-01-01 00:25:22              DRUG
# 2        190010113  2019-01-01 00:25:52              DRUG
# 3        190010114  2019-01-01 00:25:52             OBMAJ
# 4        190010115  2019-01-01 00:26:03               EDP
# 5        190073272  2019-01-07 17:49:43               EDP
# 6        190073416  2019-01-07 18:27:54               EDP
# 7        190081434  2019-01-08 10:28:31            UNKNOW
# 8        190081743  2019-01-08 11:43:35            UNKNOW
# 9        190081744  2019-01-08 11:43:48               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            6            SICK                          6
# 1                            4            DRUG                          4
# 2                            4            DRUG                          4
# ...

# %%
ems_19_first_df.tail(10)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 754646        190010100  2019-01-01 00:23:35            UNKNOW
# 754647        190010101  2019-01-01 00:23:45            INJURY
# 754648        190010103  2019-01-01 00:23:51            INJURY
# 754649        190010104  2019-01-01 00:23:57            INJURY
# 754650        190010105  2019-01-01 00:24:00             SEIZR
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 754646                            4          UNKNOW
# 754647                            5          INJURY
# 754648                            5          INJURY
# 754649                            5          INJURY
# ...

# %%
ems_19_first_df.sample(20)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 361355        190924178  2019-04-02 22:14:26              CARD
# 542560        191362931  2019-05-16 16:09:27               UNC
# 707276        191740119  2019-06-23 00:27:45            INJURY
# 428736        191084340  2019-04-18 22:57:41            INJURY
# 497391        191254279  2019-05-05 23:56:55             OTHER
# 667930        191650512  2019-06-14 04:27:31              SICK
# 486851        191231884  2019-05-03 12:34:35               EDP
# 353528        190910264  2019-04-01 02:15:36            STATEP
# 35650         190120537  2019-01-12 03:50:52               UNC
# 630723        191563047  2019-06-05 15:51:15               CVA
# 628074        191560131  2019-06-05 00:44:42            INJURY
# 254064        190663321  2019-03-07 19:03:19              SICK
# 501527        191264559  2019-05-06 21:33:18            ARREST
# 745848        190013059  2019-01-01 13:32:51             ABDPN
# ...

# %%
ems_19_first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754656 entries, 0 to 754655
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 754656 non-null  int64
#  1   INCIDENT_DATETIME               754656 non-null  object
#  2   INITIAL_CALL_TYPE               754656 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     754656 non-null  int64
#  4   FINAL_CALL_TYPE                 754656 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       754656 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       749544 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  754656 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    754656 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       748561 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         729221 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  754656 non-null  object
# ...

# %%
#the data types associated with these columns: int64, object, float64
#there are 31 columns and 754656r rows of data

# %%
#last 6 months of 2019
ems_19_last_df = pd.read_csv("Documents/wk7-data/ems_2019_last_6_months.csv")

# %%
ems_19_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             191853909  2019-07-04 21:07:53              DRUG
# 1             191864927  2019-07-05 21:09:53            MVAINJ
# 2             191870823  2019-07-06 05:32:12            INJURY
# 3             191870824  2019-07-06 05:33:49               UNC
# 4             191870897  2019-07-06 06:20:26            INJURY
# ...                 ...                  ...               ...
# 781735        192702998  2019-09-27 16:20:29               EDP
# 781736        192704269  2019-09-27 21:05:14             OTHER
# 781737        193012678  2019-10-28 15:01:30            MVAINJ
# 781738        193330212  2019-11-29 01:16:42               EDP
# 781739        193634478  2019-12-29 23:59:34               EDP
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4            DRUG
# 1                                 4          MVAINJ
# ...

# %%
### For first 6 months of 2020
ems_20_first_df = pd.read_csv("Documents/wk7-data/ems_2020_first_6_months.csv")

# %%
ems_20_first_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             201012966  2020-04-10 14:36:07              SICK
# 1             201013858  2020-04-10 17:37:57            SICKFC
# 2             201013897  2020-04-10 17:46:07             HYPTN
# 3             201014048  2020-04-10 18:19:32            SICKFC
# 4             201014049  2020-04-10 18:19:33            INJURY
# ...                 ...                  ...               ...
# 741802        201824116  2020-06-30 23:58:45            INJURY
# 741803        201824117  2020-06-30 23:59:00              DRUG
# 741804        201824118  2020-06-30 23:59:26            INJURY
# 741805        200293244  2020-01-29 17:15:18            UNKNOW
# 741806        200293566  2020-01-29 18:32:45              EDPC
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 6          SICKFC
# ...

# %%
ems_20_last_df = pd.read_csv("Documents/wk7-data/ems_2020_last_6_months.csv")

# %%
ems_20_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             201853344  2020-07-03 19:51:35            MVAINJ
# 1             201861781  2020-07-04 13:38:45            INJURY
# 2             201862931  2020-07-04 19:06:08            INJURY
# 3             201870048  2020-07-05 00:09:31              SICK
# 4             201870159  2020-07-05 00:31:24              EDPC
# ...                 ...                  ...               ...
# 670750        203664156  2020-12-31 23:58:15            DIFFBR
# 670751        203664157  2020-12-31 23:58:27            INJURY
# 670752        203664158  2020-12-31 23:58:38            CARDBR
# 670753        203664159  2020-12-31 23:58:46            MVAINJ
# 670754        203664161  2020-12-31 23:59:13            CARDBR
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4          MVAINJ
# 1                                 5          INJURY
# ...

# %%
ems_19_last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781740 entries, 0 to 781739
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 781740 non-null  int64
#  1   INCIDENT_DATETIME               781740 non-null  object
#  2   INITIAL_CALL_TYPE               781740 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     781740 non-null  int64
#  4   FINAL_CALL_TYPE                 781740 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       781740 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       776500 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  781740 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    781740 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       775362 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         756189 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  781740 non-null  object
# ...

# %%
headers19=list(ems_19_last_df.columns)
print(headers19)
# Out:
# ['CAD_INCIDENT_ID', 'INCIDENT_DATETIME', 'INITIAL_CALL_TYPE', 'INITIAL_SEVERITY_LEVEL_CODE', 'FINAL_CALL_TYPE', 'FINAL_SEVERITY_LEVEL_CODE', 'FIRST_ASSIGNMENT_DATETIME', 'VALID_DISPATCH_RSPNS_TIME_INDC', 'DISPATCH_RESPONSE_SECONDS_QY', 'FIRST_ACTIVATION_DATETIME', 'FIRST_ON_SCENE_DATETIME', 'VALID_INCIDENT_RSPNS_TIME_INDC', 'INCIDENT_RESPONSE_SECONDS_QY', 'INCIDENT_TRAVEL_TM_SECONDS_QY', 'FIRST_TO_HOSP_DATETIME', 'FIRST_HOSP_ARRIVAL_DATETIME', 'INCIDENT_CLOSE_DATETIME', 'HELD_INDICATOR', 'INCIDENT_DISPOSITION_CODE', 'BOROUGH', 'INCIDENT_DISPATCH_AREA', 'ZIPCODE', 'POLICEPRECINCT', 'CITYCOUNCILDISTRICT', 'COMMUNITYDISTRICT', 'COMMUNITYSCHOOLDISTRICT', 'CONGRESSIONALDISTRICT', 'REOPEN_INDICATOR', 'SPECIAL_EVENT_INDICATOR', 'STANDBY_INDICATOR', 'TRANSFER_INDICATOR', 'source']

# %%
ems_20_first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741807 entries, 0 to 741806
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 741807 non-null  int64
#  1   INCIDENT_DATETIME               741807 non-null  object
#  2   INITIAL_CALL_TYPE               741807 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     741807 non-null  int64
#  4   FINAL_CALL_TYPE                 741807 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       741807 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       735936 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  741807 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    741807 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       734580 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         710059 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  741807 non-null  object
# ...

# %%
headers20=list(ems_20_first_df.columns)

# %%
print(headers20)
# Out:
# ['CAD_INCIDENT_ID', 'INCIDENT_DATETIME', 'INITIAL_CALL_TYPE', 'INITIAL_SEVERITY_LEVEL_CODE', 'FINAL_CALL_TYPE', 'FINAL_SEVERITY_LEVEL_CODE', 'FIRST_ASSIGNMENT_DATETIME', 'VALID_DISPATCH_RSPNS_TIME_INDC', 'DISPATCH_RESPONSE_SECONDS_QY', 'FIRST_ACTIVATION_DATETIME', 'FIRST_ON_SCENE_DATETIME', 'VALID_INCIDENT_RSPNS_TIME_INDC', 'INCIDENT_RESPONSE_SECONDS_QY', 'INCIDENT_TRAVEL_TM_SECONDS_QY', 'FIRST_TO_HOSP_DATETIME', 'FIRST_HOSP_ARRIVAL_DATETIME', 'INCIDENT_CLOSE_DATETIME', 'HELD_INDICATOR', 'INCIDENT_DISPOSITION_CODE', 'BOROUGH', 'INCIDENT_DISPATCH_AREA', 'ZIPCODE', 'POLICEPRECINCT', 'CITYCOUNCILDISTRICT', 'COMMUNITYDISTRICT', 'COMMUNITYSCHOOLDISTRICT', 'CONGRESSIONALDISTRICT', 'REOPEN_INDICATOR', 'SPECIAL_EVENT_INDICATOR', 'STANDBY_INDICATOR', 'TRANSFER_INDICATOR', 'source']

# %%
headers19 == headers20
# Out:
# True

# %%
#confirm that one of the first is equal to one of the last
#confirm that the two lasts are the same
  #I don't know how to do this one, except that I manually see that CAP INCIDENT ID is first and source is last

# %%
## create a list to combine all 
combined_ems_df = pd.concat([ems_19_first_df,ems_19_last_df,ems_20_first_df,ems_20_last_df])

# %%
combined_ems_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             190010111  2019-01-01 00:24:51              SICK
# 1             190010112  2019-01-01 00:25:22              DRUG
# 2             190010113  2019-01-01 00:25:52              DRUG
# 3             190010114  2019-01-01 00:25:52             OBMAJ
# 4             190010115  2019-01-01 00:26:03               EDP
# ...                 ...                  ...               ...
# 670750        203664156  2020-12-31 23:58:15            DIFFBR
# 670751        203664157  2020-12-31 23:58:27            INJURY
# 670752        203664158  2020-12-31 23:58:38            CARDBR
# 670753        203664159  2020-12-31 23:58:46            MVAINJ
# 670754        203664161  2020-12-31 23:59:13            CARDBR
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 4            DRUG
# ...

# %%
#check number of rows
combined_ems_df.shape
# Out:
# (2948958, 32)

# %%
#check that number of rows equals all the dfs combined 
combined_ems_df.shape[0] == ems_19_first_df.shape[0]+ ems_19_last_df.shape[0]+ ems_20_first_df.shape[0]+ ems_20_last_df.shape[0]
# Out:
# True

# %%
## import global_temps.csv into a df called temps_df
pd.read_csv("Documents/wk7-data/global_temps.csv")
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 0               Africa  Algeria               Algiers      1    1  1995
# 1               Africa  Algeria               Algiers      1    2  1995
# 2               Africa  Algeria               Algiers      1    3  1995
# 3               Africa  Algeria               Algiers      1    4  1995
# 4               Africa  Algeria               Algiers      1    5  1995
# ...                ...      ...                   ...    ...  ...   ...
# 2906322  North America       US  San Juan Puerto Rico      7   27  2013
# 2906323  North America       US  San Juan Puerto Rico      7   28  2013
# 2906324  North America       US  San Juan Puerto Rico      7   29  2013
# 2906325  North America       US  San Juan Puerto Rico      7   30  2013
# 2906326  North America       US  San Juan Puerto Rico      7   31  2013
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# ...

# %%
temps_df = pd.read_csv("Documents/wk7-data/global_temps.csv")

# %%
temps_df
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 0               Africa  Algeria               Algiers      1    1  1995
# 1               Africa  Algeria               Algiers      1    2  1995
# 2               Africa  Algeria               Algiers      1    3  1995
# 3               Africa  Algeria               Algiers      1    4  1995
# 4               Africa  Algeria               Algiers      1    5  1995
# ...                ...      ...                   ...    ...  ...   ...
# 2906322  North America       US  San Juan Puerto Rico      7   27  2013
# 2906323  North America       US  San Juan Puerto Rico      7   28  2013
# 2906324  North America       US  San Juan Puerto Rico      7   29  2013
# 2906325  North America       US  San Juan Puerto Rico      7   30  2013
# 2906326  North America       US  San Juan Puerto Rico      7   31  2013
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# ...

# %%
temps_df.shape
# Out:
# (2906327, 7)

# %%
#so there are 2906327 rows

# %%
df = pd.read_excel("Documents/wk7-data/multi-data.xlsx")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(15)
# Out:
#     Serial Number      County License Type Code License Class Code  \
# 0         2000777      ALBANY                HL                242
# 1         1197749      NASSAU                CT                246
# 2         2149537    SULLIVAN                AX                122
# 3         1311950      QUEENS                 W                322
# 4         2217319      PUTNAM                TW                344
# 5         1319511    NEW YORK                RW                341
# 6         2220767  MONTGOMERY                 C                103
# 7         2129283      ALBANY                WS                308
# 8         2138381      ALBANY                WS                308
# 9         2160505      ALBANY                WS                308
# 10        2175892      ALBANY                WS                308
# 11        2188886      ALBANY                WS                308
# 12        2192454      ALBANY                WS                308
# ...
